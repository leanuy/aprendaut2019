# %%
import getConfusionMatrix.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-165a6b033525> in <module>
# ----> 1 import getConfusionMatrix.py
#
# ModuleNotFoundError: No module named 'getConfusionMatrix.py'; 'getConfusionMatrix' is not a package
